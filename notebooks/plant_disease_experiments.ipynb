# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
# Chemin du modèle
model_path = '../models/vgg16_finetuned.h5'

# Vérifier l'existence
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Modèle introuvable : {model_path}")

# Charger le modèle
model = load_model(model_path)
print("✅ Modèle chargé avec succès !")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Modèle chargé avec succès !

# %%
# Chemins vers les dossiers
train_dir = '../data/Chili_Plant_Disease/train'
test_dir = '../data/Chili_Plant_Disease/test'

# Chemin vers le modèle
model_path = 'models/vgg16_finetuned.h5'
history_path = 'models/history.pkl'

# %%
import os

# Vérifie où Python pense être le dossier courant
print("Dossier courant :", os.getcwd())

# Liste les fichiers du dossier models
print("Contenu du dossier models :", os.listdir('../models'))  # '../models' si notebook est dans 'notebooks'
# Out:
# Dossier courant : d:\PlantDisease\notebooks
# Contenu du dossier models : ['history.pkl', 'vgg16_finetuned.h5']

# %%
import pickle

# Charger l'historique sauvegardé
history_path = '../models/history.pkl'
if not os.path.exists(history_path):
    raise FileNotFoundError(f"Historique introuvable : {history_path}")

with open(history_path, 'rb') as f:
    history = pickle.load(f)

# Tracer les courbes
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history['accuracy'], label='Train Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Train vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history['loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Train vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
